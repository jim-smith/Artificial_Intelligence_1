# %% [markdown]
# # AIML Portfolio Self-check
#
# ## TO USE THIS NOTEBOOK RUN EACH CELL ONE BY ONE
# ### If you get errors (red boxes appear) fix them before you move on.
#
# <div class="alert alert-block alert-danger"> <b>REMEMBER:</b> You need to make sure you are running this code within the virtual environment you created using 'AIenv'.<br> In Jupyter click on the kernel menu then change-kernel. In VSCode use the kernel selector in the top-right hand corner </div>

# %% [markdown]
# ### 1: Develop your aiml code in the next cell
# ### and run the cell to write it to file

# %%
# %%writefile "student.aiml"
# <aiml>
#
# <!-- delete the useless category below and put your code  after this comment-->
# <category>
#   <pattern> * </pattern>
#  <template> I have no answer for that.</template>
# </category>
#
# </aiml>
# Out:
# Overwriting student.aiml

# %% [markdown]
# ### 2: Run the next code cell to:
# - do some imports
# - create a marker object
# - load the 45 questions-response pairs

# %%
from aimlmarker import AIMLMarker

my_marker = AIMLMarker()

my_marker.load_questions()

# %% [markdown]
# ### 3:Provided that runs ok, run the next cell to load and test your aiml

# %%
my_marker.test_aiml()
print(f"Score is {my_marker.score}")
feedback = my_marker.feedback_str.replace("&lt;", "<").replace("&gt;", ">")

print(f"Feedback is:\n{feedback}")
# Out:
# Loading student.aiml...done (0.00 seconds)
# Score is 0
# Feedback is:
# 45 question-response pairs read for testing your bot.
# AIML file student.aiml passes basic xml syntax checks.
# Passed aiml-specific syntax check.
# After reading your file the bot has 1 categories.
# Your bot answered 45 questions incorrectly.
# File student-responses.txt has more details of your bots responses.
# Common mistakes are typos or extra spaces.
# Your bot answered incorrectly for 3 questions that require a sense of context.
# To answer these you will need to use <that> tag pairs in your categories, or to access the value held in the bot's <that/> variable (predicate).

# %% [markdown]
# ### 4: Repeat step3 until there are no errors.
# ### Then you can run the next cell to see what your bot responded for each question

# %%
# !cat "student-responses.txt"
# Out:
# Q37: What is a rule mybot?
# Expected response: A rule is a statement that generates new knowledge by asserting that if one fact is true, then another is also true.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS A RULE MYBOT Q33: Provide an example of short-term domain-specific knowledge.
# Expected response: The deadline for the submission of this portfolio.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PROVIDE AN EXAMPLE OF SHORT TERM DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q25: Illustrate the concept of long-term domain-specific knowledge.
# Expected response: The formal specification of a particular machine learning algorithm.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	ILLUSTRATE THE CONCEPT OF LONG TERM DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q10: Give me an example of a rule.
# Expected response: If isAlive(X) then NOT isDead(X).
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME AN EXAMPLE OF A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q22: Tell me about a fact.
# Expected response: A fact is a statement which asserts that a relationship holds for an object-subject pair.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	TELL ME ABOUT A FACT 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q20: Tell me about generic knowledge.
# Expected response: Generic knowledge is relevant to more than one application or domain.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	TELL ME ABOUT GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q39: Please myBot what is a rule?
# Expected response: A rule is a statement that generates new knowledge by asserting that if one fact is true, then another is also true.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PLEASE MYBOT WHAT IS A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q32: Provide an example of short-term generic knowledge.
# Expected response: The date today is an example as it may be useful in different contexts but only lasts 24 hours.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PROVIDE AN EXAMPLE OF SHORT TERM GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q13: Give me a definition of short-term knowledge.
# Expected response: Short-term knowledge is only valid for a particular situation or run of a programme.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME A DEFINITION OF SHORT TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 2: What is generic knowledge?
# Expected response: Generic knowledge is relevant to more than one application or domain.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 5: What is a rule?
# Expected response: A rule is a statement that generates new knowledge by asserting that if one fact is true, then another is also true.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q27: Illustrate the concept of short-term domain-specific knowledge.
# Expected response: The deadline for the submission of this portfolio.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	ILLUSTRATE THE CONCEPT OF SHORT TERM DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 6: Give me an example of long-term generic knowledge.
# Expected response: The formal specification of the python programming language.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME AN EXAMPLE OF LONG TERM GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 7: Give me an example of long-term domain-specific knowledge.
# Expected response: The formal specification of a particular machine learning algorithm.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME AN EXAMPLE OF LONG TERM DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q17: Give me a definition of a rule.
# Expected response: A rule is a statement that generates new knowledge by asserting that if one fact is true, then another is also true.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME A DEFINITION OF A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q12: Give me a definition of long-term knowledge?
# Expected response: Long-term knowledge is valid over a period of time.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME A DEFINITION OF LONG TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 9: Give me an example of short-term domain-specific knowledge.
# Expected response: The deadline for the submission of this portfolio.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME AN EXAMPLE OF SHORT TERM DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q31: Provide an example of long-term domain-specific knowledge.
# Expected response: The formal specification of a particular machine learning algorithm.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PROVIDE AN EXAMPLE OF LONG TERM DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 0: What is long-term knowledge?
# Expected response: Long-term knowledge is valid over a period of time.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS LONG TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q14: Give me a definition of generic knowledge.
# Expected response: Generic knowledge is relevant to more than one application or domain.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME A DEFINITION OF GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q38: Please give me an example of a rule.
# Expected response: If isAlive(X) then NOT isDead(X).
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PLEASE GIVE ME AN EXAMPLE OF A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q23: Tell me about a rule.
# Expected response: A rule is a statement that generates new knowledge by asserting that if one fact is true, then another is also true.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	TELL ME ABOUT A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q11: Give me an example of a fact.
# Expected response: Submissions for this module are run through automatic and effective plagiarism checks.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME AN EXAMPLE OF A FACT 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q26: Illustrate the concept of short-term generic knowledge.
# Expected response: The date today is an example as it may be useful in different contexts but only lasts 24 hours.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	ILLUSTRATE THE CONCEPT OF SHORT TERM GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q30: Provide an example of long-term generic knowledge.
# Expected response: The formal specification of the python programming language.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PROVIDE AN EXAMPLE OF LONG TERM GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q40: Mybot please give me a definition of a rule.
# Expected response: A rule is a statement that generates new knowledge by asserting that if one fact is true, then another is also true.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	MYBOT PLEASE GIVE ME A DEFINITION OF A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q29: Illustrate the concept of a rule.
# Expected response: If isAlive(X) then NOT isDead(X).
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	ILLUSTRATE THE CONCEPT OF A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 4: What is a fact?
# Expected response: A fact is a statement which asserts that a relationship holds for an object-subject pair.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS A FACT 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q21: Tell me about domain-specific knowledge.
# Expected response: Domain-specific knowledge is only applicable to one specific application or domain.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	TELL ME ABOUT DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 1: What is short-term knowledge?
# Expected response: Short-term knowledge is only valid for a particular situation or run of a programme.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS SHORT TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q36: Please provide an example of a rule.
# Expected response: If isAlive(X) then NOT isDead(X).
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PLEASE PROVIDE AN EXAMPLE OF A RULE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q28: Illustrate the concept of a fact.
# Expected response: Submissions for this module are run through automatic and effective plagiarism checks.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	ILLUSTRATE THE CONCEPT OF A FACT 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q24: Illustrate the concept of long-term generic knowledge.
# Expected response: The formal specification of the python programming language.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	ILLUSTRATE THE CONCEPT OF LONG TERM GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q16: Give me a definition of a fact.
# Expected response: A fact is a statement which asserts that a relationship holds for an object-subject pair.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME A DEFINITION OF A FACT 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q18: Tell me about long-term knowledge?
# Expected response: Long-term knowledge is valid over a period of time.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	TELL ME ABOUT LONG TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q15: Give me a definition of domain-specific knowledge.
# Expected response: Domain-specific knowledge is only applicable to one specific application or domain.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME A DEFINITION OF DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 8: Give me an example of short-term generic knowledge.
# Expected response: The date today is an example as it may be useful in different contexts but only lasts 24 hours.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	GIVE ME AN EXAMPLE OF SHORT TERM GENERIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q19: Tell me about short-term knowledge.
# Expected response: Short-term knowledge is only valid for a particular situation or run of a programme.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	TELL ME ABOUT SHORT TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q 3: What is domain-specific knowledge?
# Expected response: Domain-specific knowledge is only applicable to one specific application or domain.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS DOMAIN SPECIFIC KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q34: Please provide an example of a fact.
# Expected response: Submissions for this module are run through automatic and effective plagiarism checks.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	PLEASE PROVIDE AN EXAMPLE OF A FACT 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q35: Why is knowing that useful?
# Expected response: To remind you that we take assessment offences very seriously.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHY IS KNOWING THAT USEFUL 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q41: What is the way that AIML allows variables in its long-term knowledge.
# Expected response: AIML has wildcards and srai for that purpose.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS THE WAY THAT AIML ALLOWS VARIABLES IN ITS LONG TERM KNOWLEDGE 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q42: Why is knowing that useful?
# Expected response: Because it allows us to make statements that apply to classes of things or questions.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHY IS KNOWING THAT USEFUL 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q43: What is the way AIML supports context during a conversation.
# Expected response: AIML supports context through the use of the that tag to refer to previous bot answers, and via setting variables such as topic.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHAT IS THE WAY AIML SUPPORTS CONTEXT DURING A CONVERSATION 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
# Q44: Why is knowing that useful?
# Expected response: Because some words like that and it can only be understood in the context of previous sentences.
# Your bot response: I have no answer for that.
# Question answered incorrectly
#
# 	 The input gets preprocessed by your bot as :
# 	WHY IS KNOWING THAT USEFUL 	 value for the <that> variable which might affect matches is:	I have no answer for that.
#
#  In total you got 0 questions correct.
